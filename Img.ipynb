# %%
import requests
url = 'https://gateway.pinata.cloud/ipfs/QmTqXn73aVhFjRw317oNPvGzBurDwfqSmadneA4VaVbfdH/2125.png'
r = requests.get(url, allow_redirects=True)
open('demi#2125.png', 'wb').write(r.content)
# Out:
# 1572734

# %%
from PIL import Image

image = Image.open('demi#2125.png')
image.show()

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('demi#2125.png')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
